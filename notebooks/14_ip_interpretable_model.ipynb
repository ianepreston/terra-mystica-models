# %% [markdown]
# I can set up how I build the model and the coefficients to make it easier to interpret. Let's do that.
#
# Basically I dropped the constant term so that I could have an indicator variable for each faction. There's also some underlying cleanup in how the prediction dataframe is generated that's improving my results. Looking at the faction_{faction_name} coefficients is a little confusing, because their overall expected margin is going to be that base plus the coefficients on their bonus and score interactions. The main thing to focus on here is how the bonus and score interactions for the factions look. In all cases the bonus coefficients are relative to the impact of BONUS1 and the score tiles are relative to SCORE2

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from terra_mystica_models.features.model_data import player_level_df
from terra_mystica_models.models import train_model

# %%
predict_df = player_level_df()

# %%
score_turn_model = train_model.score_turn_model(predict_df)
score_turn_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              vp_margin   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     21.14
# Date:                Sun, 05 Apr 2020   Prob (F-statistic):               0.00
# Time:                        18:13:20   Log-Likelihood:            -8.4160e+05
# No. Observations:              198960   AIC:                         1.685e+06
# Df Residuals:                  198175   BIC:                         1.693e+06
# Df Model:                         784
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------
# ...
