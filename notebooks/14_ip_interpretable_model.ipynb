# %% [markdown]
# I can set up how I build the model and the coefficients to make it easier to interpret. Let's do that.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from terra_mystica_models.features.model_data import player_level_df
from terra_mystica_models.models import train_model

# %%
predict_df = player_level_df()

# %%
score_turn_model = train_model.score_turn_model(predict_df)
score_turn_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:              vp_margin   R-squared (uncentered):                   0.076
# Model:                            OLS   Adj. R-squared (uncentered):              0.072
# Method:                 Least Squares   F-statistic:                              20.97
# Date:                Sun, 05 Apr 2020   Prob (F-statistic):                        0.00
# Time:                        17:47:54   Log-Likelihood:                     -8.4175e+05
# No. Observations:              198960   AIC:                                  1.685e+06
# Df Residuals:                  198185   BIC:                                  1.693e+06
# Df Model:                         775
# Covariance Type:            nonrobust
# ...
#                                                    coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# I don't like that warning, and what I'm doing is starting to look a lot like just making an individual model for each faction. That would certainly be easier to interpret. Let's try that
