# %% [markdown]
# # More modeling
#
# After a cleanup of the code from notebook 10 let's build some more features into our model

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import statsmodels.api as sm
pd.options.display.max_columns = 50

# %%
from terra_mystica_models.features.model_data import player_level_df
from terra_mystica_models.models import train_model

# %% [markdown]
# ## Setup and validate refactor

# %%
predict_df = player_level_df()

# %% [markdown]
# Start by re-running the model from the previous notebook, just to make sure nothing weird happened on the refactor

# %%
simple_model = train_model.simple_model(predict_df)
simple_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              vp_margin   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     464.2
# Date:                Sun, 29 Mar 2020   Prob (F-statistic):               0.00
# Time:                        11:38:31   Log-Likelihood:            -8.4639e+05
# No. Observations:              198960   AIC:                         1.693e+06
# Df Residuals:                  198945   BIC:                         1.693e+06
# Df Model:                          14
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -3.7683      0.220    -17.166      0.000      -4.199      -3.338
# player_num                -0.3301      0.035     -9.372      0.000      -0.399      -0.261
# faction_auren             -0.2274      0.315     -0.723      0.470      -0.844       0.389
# faction_chaosmagicians     4.0712      0.233     17.444      0.000       3.614       4.529
# faction_cultists           6.7553      0.257     26.303      0.000       6.252       7.259
# faction_darklings          9.7877      0.225     43.527      0.000       9.347      10.228
# faction_dwarves            3.3857      0.284     11.904      0.000       2.828       3.943
# faction_engineers          6.3924      0.240     26.622      0.000       5.922       6.863
# faction_fakirs            -4.2379      0.396    -10.692      0.000      -5.015      -3.461
# faction_giants            -1.0285      0.298     -3.446      0.001      -1.613      -0.443
# faction_halflings          2.8698      0.251     11.445      0.000       2.378       3.361
# faction_mermaids           4.2740      0.239     17.872      0.000       3.805       4.743
# faction_nomads             3.1887      0.234     13.650      0.000       2.731       3.647
# faction_swarmlings         2.6398      0.249     10.585      0.000       2.151       3.129
# faction_witches            4.4320      0.240     18.481      0.000       3.962       4.902
# ==============================================================================
# Omnibus:                     1026.977   Durbin-Watson:                   2.495
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1251.219
# Skew:                          -0.107   Prob(JB):                    2.00e-272
# Kurtosis:                       3.325   Cond. No.                         59.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Ok, that's always nice to see, the refactor didn't mess things up. Let's move on to test some more assumptions and then build the model that will actually identify what we care about

# %% [markdown]
# ## Check some assumptions
#
# The thing we actually care about here is how the presence of various bonus or scoring tiles impacts our faction preference. To accomplish this I'm going to try and estimate the marginal impact of specific scoring/bonus tiles conditional on the player being a specific faction. I have a binary column identifying whether or not a player is playing each faction, and a binary outcome for if a specific scoring or bonus tile is present (and in the case of scoring tiles I can further narrow that down to which turn it's present for). Finally, I've generated interaction terms that are true when both the faction and the tile condition are met. For example, if a player is the swarmlings and bonus tile 1 is present then the column "faction_swarmlings_x_BON1" will be true. If either of those conditions is not met then it will be false. The coefficient assigned to that tile is the estimated marginal impact of score from that combination. In the case of factions we have pretty convincing evidence from the initial regression that we'll need to consider their impact on their own, on top of the interaction impact. As an example, say we find that the coefficient for "faction_fakir_x_BON2" 2, and that this is greater than the coefficient for any of the other faction coefficients with BON2. This still doesn't mean that you should pick the Fakirs when BON2 is present. Their base penalty is such that they're still quite possibly a poor choice. What we really want is to find which faction has the highest marginal score based on its base level on top of its interaction coefficients for a given game setup.
#
# So based on this I clearly need to include the standalone faction indicators in my regression in addition to their interactions. However, I don't think I should have to include the standalone indicators for the scoring or bonus tiles. Because those are constant for all players, any advantage they give to one player should be offset by a net disadvantage across the other three players. Therefore their overall marginal impact on victory point margin should be zero. Let's do a regression to make sure that is indeed the case.

# %%
assumption_test_model = train_model.base_score_model(predict_df)
assumption_test_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              vp_margin   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     211.1
# Date:                Sun, 29 Mar 2020   Prob (F-statistic):               0.00
# Time:                        11:38:32   Log-Likelihood:            -8.4637e+05
# No. Observations:              198960   AIC:                         1.693e+06
# Df Residuals:                  198928   BIC:                         1.693e+06
# Df Model:                          31
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -3.8976      0.714     -5.458      0.000      -5.297      -2.498
# player_num                -0.3276      0.035     -9.301      0.000      -0.397      -0.259
# faction_auren             -0.2148      0.315     -0.682      0.495      -0.832       0.403
# faction_chaosmagicians     4.1234      0.234     17.643      0.000       3.665       4.581
# faction_cultists           6.8308      0.257     26.548      0.000       6.326       7.335
# faction_darklings          9.8812      0.226     43.799      0.000       9.439      10.323
# faction_dwarves            3.4167      0.285     11.984      0.000       2.858       3.976
# faction_engineers          6.5009      0.241     27.000      0.000       6.029       6.973
# faction_fakirs            -4.1955      0.397    -10.575      0.000      -4.973      -3.418
# faction_giants            -0.9968      0.299     -3.335      0.001      -1.583      -0.411
# faction_halflings          2.9161      0.252     11.573      0.000       2.422       3.410
# faction_mermaids           4.3736      0.240     18.221      0.000       3.903       4.844
# faction_nomads             3.2500      0.234     13.890      0.000       2.791       3.709
# faction_swarmlings         2.6722      0.250     10.695      0.000       2.183       3.162
# faction_witches            4.4847      0.240     18.662      0.000       4.014       4.956
# BON2                      -0.0380      0.113     -0.337      0.736      -0.259       0.183
# BON3                      -0.1041      0.113     -0.922      0.356      -0.325       0.117
# BON4                       0.0472      0.113      0.418      0.676      -0.174       0.268
# BON5                       0.0254      0.113      0.224      0.823      -0.196       0.247
# BON6                       0.1381      0.112      1.228      0.219      -0.082       0.358
# BON7                       0.0645      0.112      0.574      0.566      -0.156       0.285
# BON8                      -0.1138      0.113     -1.007      0.314      -0.335       0.108
# BON9                       0.0428      0.113      0.380      0.704      -0.178       0.263
# BON10                     -0.1052      0.110     -0.960      0.337      -0.320       0.110
# SCORE2                    -0.0123      0.108     -0.114      0.909      -0.225       0.200
# SCORE3                    -0.0144      0.108     -0.133      0.894      -0.227       0.198
# SCORE4                     0.1343      0.109      1.232      0.218      -0.079       0.348
# SCORE5                     0.0663      0.108      0.612      0.541      -0.146       0.279
# SCORE6                    -0.0092      0.108     -0.085      0.933      -0.222       0.203
# SCORE7                     0.1225      0.109      1.127      0.260      -0.091       0.335
# SCORE8                     0.0583      0.108      0.539      0.590      -0.154       0.270
# SCORE9                    -0.3687      0.104     -3.551      0.000      -0.572      -0.165
# ==============================================================================
# Omnibus:                     1049.853   Durbin-Watson:                   2.496
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1277.210
# Skew:                          -0.109   Prob(JB):                    4.54e-278
# Kurtosis:                       3.326   Cond. No.                         88.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# OK, all of the bonus or scoring tiles have individual coefficients that are not statistically significantly different than zero (look at the last two columns for the confidence interval, since they contain 0 we can say they're not significant. I can do a more formal test to determine if they're jointly significant or not, just to be safe.

# %% [markdown]
# For comparison let's first test the assumption that faction choice has no impact on marginal points.

# %%
factions = ['faction_auren', 'faction_chaosmagicians',
       'faction_cultists', 'faction_darklings', 'faction_dwarves',
       'faction_engineers', 'faction_fakirs', 'faction_giants',
       'faction_halflings', 'faction_mermaids', 'faction_nomads',
       'faction_swarmlings', 'faction_witches']
hypotheses = ", ".join(f"({faction} = 0)" for faction in factions)
f_test = assumption_test_model.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=array([[467.46892028]]), p=0.0, df_denom=1.99e+05, df_num=13>

# %% [markdown]
# For this one we can reject the null hypothesis, which was that jointly all of the faction impacts are = to 0

# %% [markdown]
# Ok, now let's test the ones we care about

# %%
hypotheses = ", ".join(f"(BON{i} = 0)" for i in range(2, 11))
f_test = assumption_test_model.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=array([[1.13040284]]), p=0.3366194633898626, df_denom=1.99e+05, df_num=9>

# %%
hypotheses = ", ".join(f"(SCORE{i} = 0)" for i in range(2, 10))
f_test = assumption_test_model.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=array([[4.03661717]]), p=8.260628182910269e-05, df_denom=1.99e+05, df_num=8>

# %% [markdown]
# Interesting. As we'd expect, the bonus tiles don't have any impact on victory point margin, but the scoring tiles seem to have a very small but statistically significant one. I'm not totally sure what to make of this, but the effect is still quite small so I think at least for a first pass we can still exclude the base scoring tile features. Just as one final test it looks like SCORE9 is the only one that's individually significant, let's see what happens if I exclude it from the test

# %%
hypotheses = ", ".join(f"(SCORE{i} = 0)" for i in range(2, 9))
f_test = assumption_test_model.f_test(hypotheses)
print(f_test)
# Out:
# <F test: F=array([[0.60436588]]), p=0.752870331313469, df_denom=1.99e+05, df_num=7>

# %% [markdown]
# Ok, so it is just SCORE9. I remember that being an expansion tile, but still I'm not sure how that would relate to a difference. Worth keeping in mind though.

# %% [markdown]
# ## The actual model we care about
#
# Let's see what these interaction effects look like

# %%
interact_model = train_model.interact_model(predict_df)
interact_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              vp_margin   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     40.21
# Date:                Sun, 29 Mar 2020   Prob (F-statistic):               0.00
# Time:                        11:38:37   Log-Likelihood:            -8.4497e+05
# No. Observations:              198960   AIC:                         1.690e+06
# Df Residuals:                  198724   BIC:                         1.693e+06
# Df Model:                         235
# Covariance Type:            nonrobust
# ===================================================================================================
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              -4.0918      0.218    -18.738      0.000      -4.520      -3.664
# player_num                         -0.1919      0.035     -5.434      0.000      -0.261      -0.123
# faction_auren                      -7.0841      4.223     -1.677      0.093     -15.361       1.193
# faction_chaosmagicians              7.6305      2.015      3.787      0.000       3.682      11.579
# faction_cultists                   25.9287      2.779      9.329      0.000      20.481      31.376
# faction_darklings                   3.3317      1.674      1.991      0.047       0.052       6.612
# faction_dwarves                    32.6837      3.633      8.995      0.000      25.562      39.805
# faction_engineers                  22.6196      2.259     10.012      0.000      18.192      27.047
# faction_fakirs                    -14.8806      6.162     -2.415      0.016     -26.958      -2.803
# faction_giants                    -12.9394      3.790     -3.414      0.001     -20.368      -5.511
# faction_halflings                  33.2951      2.827     11.778      0.000      27.755      38.835
# faction_mermaids                   -3.6855      2.215     -1.664      0.096      -8.028       0.657
# faction_nomads                     -9.2222      1.987     -4.641      0.000     -13.117      -5.328
# faction_swarmlings                -12.1265      2.544     -4.766      0.000     -17.114      -7.139
# faction_witches                    -3.8495      2.243     -1.716      0.086      -8.247       0.547
# faction_auren_x_BON2               -0.0467      0.701     -0.067      0.947      -1.420       1.326
# faction_auren_x_BON3                0.0151      0.708      0.021      0.983      -1.373       1.403
# faction_auren_x_BON4                1.1663      0.718      1.625      0.104      -0.240       2.573
# faction_auren_x_BON5                0.3630      0.704      0.515      0.606      -1.017       1.743
# faction_auren_x_BON6                1.7190      0.701      2.454      0.014       0.346       3.092
# faction_auren_x_BON7                0.5826      0.706      0.826      0.409      -0.800       1.966
# faction_auren_x_BON8                0.9814      0.711      1.380      0.168      -0.412       2.375
# faction_auren_x_BON9               -0.0498      0.701     -0.071      0.943      -1.423       1.324
# faction_auren_x_BON10              -0.5802      0.662     -0.876      0.381      -1.878       0.718
# faction_chaosmagicians_x_BON2      -0.5301      0.333     -1.593      0.111      -1.182       0.122
# faction_chaosmagicians_x_BON3       0.0037      0.335      0.011      0.991      -0.652       0.660
# faction_chaosmagicians_x_BON4      -0.5304      0.337     -1.572      0.116      -1.192       0.131
# faction_chaosmagicians_x_BON5      -0.8527      0.335     -2.549      0.011      -1.508      -0.197
# faction_chaosmagicians_x_BON6       0.4111      0.335      1.226      0.220      -0.246       1.068
# faction_chaosmagicians_x_BON7      -0.8703      0.331     -2.626      0.009      -1.520      -0.221
# faction_chaosmagicians_x_BON8      -0.1991      0.335     -0.595      0.552      -0.855       0.457
# faction_chaosmagicians_x_BON9      -0.4788      0.333     -1.440      0.150      -1.131       0.173
# faction_chaosmagicians_x_BON10      0.8251      0.326      2.527      0.011       0.185       1.465
# faction_cultists_x_BON2            -2.0050      0.466     -4.300      0.000      -2.919      -1.091
# faction_cultists_x_BON3            -2.0521      0.465     -4.416      0.000      -2.963      -1.141
# faction_cultists_x_BON4            -3.0138      0.465     -6.477      0.000      -3.926      -2.102
# faction_cultists_x_BON5            -2.5541      0.467     -5.464      0.000      -3.470      -1.638
# faction_cultists_x_BON6            -3.9485      0.461     -8.568      0.000      -4.852      -3.045
# faction_cultists_x_BON7            -2.6407      0.463     -5.705      0.000      -3.548      -1.734
# faction_cultists_x_BON8            -4.0198      0.458     -8.769      0.000      -4.918      -3.121
# faction_cultists_x_BON9            -2.4142      0.465     -5.191      0.000      -3.326      -1.503
# faction_cultists_x_BON10           -2.2747      0.452     -5.037      0.000      -3.160      -1.390
# faction_darklings_x_BON2            2.6061      0.278      9.370      0.000       2.061       3.151
# faction_darklings_x_BON3            2.9253      0.279     10.502      0.000       2.379       3.471
# faction_darklings_x_BON4            2.9329      0.275     10.662      0.000       2.394       3.472
# faction_darklings_x_BON5            2.6901      0.277      9.705      0.000       2.147       3.233
# faction_darklings_x_BON6            2.4150      0.275      8.795      0.000       1.877       2.953
# faction_darklings_x_BON7            2.4711      0.274      9.004      0.000       1.933       3.009
# faction_darklings_x_BON8            3.0272      0.284     10.661      0.000       2.471       3.584
# faction_darklings_x_BON9            2.8069      0.275     10.217      0.000       2.268       3.345
# faction_darklings_x_BON10           0.6325      0.268      2.359      0.018       0.107       1.158
# faction_dwarves_x_BON2             -2.7552      0.589     -4.677      0.000      -3.910      -1.601
# faction_dwarves_x_BON3             -3.7508      0.590     -6.355      0.000      -4.908      -2.594
# faction_dwarves_x_BON4             -3.2554      0.577     -5.644      0.000      -4.386      -2.125
# faction_dwarves_x_BON5             -1.1353      0.602     -1.885      0.059      -2.316       0.045
# faction_dwarves_x_BON6             -1.2932      0.588     -2.201      0.028      -2.445      -0.142
# faction_dwarves_x_BON7             -1.9533      0.589     -3.314      0.001      -3.109      -0.798
# faction_dwarves_x_BON8             -1.4382      0.587     -2.448      0.014      -2.590      -0.287
# faction_dwarves_x_BON9             -1.9010      0.593     -3.207      0.001      -3.063      -0.739
# faction_dwarves_x_BON10            -3.0246      0.562     -5.378      0.000      -4.127      -1.922
# faction_engineers_x_BON2           -1.9855      0.374     -5.305      0.000      -2.719      -1.252
# faction_engineers_x_BON3           -2.2883      0.372     -6.155      0.000      -3.017      -1.560
# faction_engineers_x_BON4           -3.6024      0.375     -9.608      0.000      -4.337      -2.868
# faction_engineers_x_BON5           -0.6955      0.378     -1.839      0.066      -1.437       0.046
# faction_engineers_x_BON6           -1.8491      0.375     -4.925      0.000      -2.585      -1.113
# faction_engineers_x_BON7           -0.9177      0.377     -2.434      0.015      -1.657      -0.179
# faction_engineers_x_BON8           -1.7644      0.376     -4.696      0.000      -2.501      -1.028
# faction_engineers_x_BON9           -2.7391      0.376     -7.284      0.000      -3.476      -2.002
# faction_engineers_x_BON10          -0.4991      0.369     -1.351      0.177      -1.223       0.225
# faction_fakirs_x_BON2              -1.9176      1.058     -1.813      0.070      -3.991       0.156
# faction_fakirs_x_BON3              -1.4869      1.054     -1.411      0.158      -3.552       0.579
# faction_fakirs_x_BON4              -0.8234      1.026     -0.803      0.422      -2.834       1.187
# faction_fakirs_x_BON5              -1.0925      1.064     -1.027      0.305      -3.178       0.993
# faction_fakirs_x_BON6              -3.1259      1.032     -3.029      0.002      -5.149      -1.103
# faction_fakirs_x_BON7              -1.2660      1.051     -1.204      0.229      -3.327       0.795
# faction_fakirs_x_BON8              -1.9135      1.081     -1.770      0.077      -4.032       0.205
# faction_fakirs_x_BON9              -2.5415      1.055     -2.409      0.016      -4.609      -0.474
# faction_fakirs_x_BON10             -2.7863      1.005     -2.772      0.006      -4.756      -0.816
# faction_giants_x_BON2               2.7584      0.627      4.399      0.000       1.529       3.987
# faction_giants_x_BON3               2.9625      0.623      4.758      0.000       1.742       4.183
# faction_giants_x_BON4               2.6626      0.623      4.277      0.000       1.442       3.883
# faction_giants_x_BON5               3.1289      0.635      4.929      0.000       1.885       4.373
# faction_giants_x_BON6               4.4382      0.628      7.065      0.000       3.207       5.670
# faction_giants_x_BON7               2.6877      0.624      4.306      0.000       1.464       3.911
# faction_giants_x_BON8               2.8686      0.622      4.610      0.000       1.649       4.088
# faction_giants_x_BON9               3.7860      0.622      6.086      0.000       2.567       5.005
# faction_giants_x_BON10              1.1278      0.593      1.901      0.057      -0.035       2.291
# faction_halflings_x_BON2           -0.5501      0.431     -1.276      0.202      -1.395       0.295
# faction_halflings_x_BON3           -0.6024      0.433     -1.390      0.164      -1.452       0.247
# faction_halflings_x_BON4            0.0805      0.429      0.188      0.851      -0.761       0.922
# faction_halflings_x_BON5            0.4546      0.432      1.051      0.293      -0.393       1.302
# faction_halflings_x_BON6           -1.6561      0.427     -3.883      0.000      -2.492      -0.820
# faction_halflings_x_BON7           -0.9081      0.429     -2.119      0.034      -1.748      -0.068
# faction_halflings_x_BON8           -0.9173      0.428     -2.145      0.032      -1.756      -0.079
# faction_halflings_x_BON9            0.5272      0.430      1.227      0.220      -0.315       1.369
# faction_halflings_x_BON10          -1.9171      0.416     -4.608      0.000      -2.733      -1.102
# faction_mermaids_x_BON2            -0.5692      0.367     -1.551      0.121      -1.288       0.150
# faction_mermaids_x_BON3            -1.1495      0.367     -3.133      0.002      -1.869      -0.430
# faction_mermaids_x_BON4             0.0715      0.367      0.195      0.846      -0.648       0.791
# faction_mermaids_x_BON5            -0.9493      0.367     -2.590      0.010      -1.668      -0.231
# faction_mermaids_x_BON6            -2.5884      0.359     -7.213      0.000      -3.292      -1.885
# faction_mermaids_x_BON7            -0.9356      0.362     -2.584      0.010      -1.645      -0.226
# faction_mermaids_x_BON8            -0.8354      0.362     -2.306      0.021      -1.545      -0.125
# faction_mermaids_x_BON9            -0.4292      0.367     -1.170      0.242      -1.148       0.290
# faction_mermaids_x_BON10            4.0429      0.385     10.510      0.000       3.289       4.797
# faction_nomads_x_BON2               0.3670      0.332      1.106      0.269      -0.284       1.017
# faction_nomads_x_BON3               0.5927      0.331      1.788      0.074      -0.057       1.242
# faction_nomads_x_BON4               0.8265      0.330      2.507      0.012       0.180       1.473
# faction_nomads_x_BON5              -0.2809      0.332     -0.847      0.397      -0.931       0.369
# faction_nomads_x_BON6               1.2988      0.331      3.924      0.000       0.650       1.947
# faction_nomads_x_BON7               0.2931      0.330      0.888      0.374      -0.354       0.940
# faction_nomads_x_BON8              -0.7294      0.329     -2.217      0.027      -1.374      -0.084
# faction_nomads_x_BON9               0.9423      0.331      2.847      0.004       0.294       1.591
# faction_nomads_x_BON10             -0.1706      0.319     -0.535      0.593      -0.796       0.455
# faction_swarmlings_x_BON2           0.5124      0.424      1.210      0.226      -0.318       1.342
# faction_swarmlings_x_BON3          -0.0212      0.427     -0.050      0.960      -0.858       0.816
# faction_swarmlings_x_BON4           0.6564      0.422      1.554      0.120      -0.171       1.484
# faction_swarmlings_x_BON5          -0.0368      0.426     -0.086      0.931      -0.871       0.798
# faction_swarmlings_x_BON6           3.0318      0.433      6.997      0.000       2.183       3.881
# faction_swarmlings_x_BON7           2.3930      0.432      5.544      0.000       1.547       3.239
# faction_swarmlings_x_BON8           0.2659      0.429      0.620      0.535      -0.574       1.106
# faction_swarmlings_x_BON9          -0.9553      0.421     -2.270      0.023      -1.780      -0.130
# faction_swarmlings_x_BON10          0.6660      0.403      1.652      0.099      -0.124       1.456
# faction_witches_x_BON2              0.1720      0.373      0.461      0.645      -0.560       0.904
# faction_witches_x_BON3              0.2047      0.376      0.544      0.586      -0.532       0.942
# faction_witches_x_BON4              0.0203      0.379      0.054      0.957      -0.723       0.763
# faction_witches_x_BON5             -0.8441      0.370     -2.280      0.023      -1.570      -0.118
# faction_witches_x_BON6             -0.3014      0.368     -0.819      0.413      -1.023       0.420
# faction_witches_x_BON7             -0.6577      0.371     -1.773      0.076      -1.385       0.069
# faction_witches_x_BON8             -0.5597      0.371     -1.509      0.131      -1.287       0.167
# faction_witches_x_BON9             -0.2355      0.373     -0.632      0.527      -0.966       0.495
# faction_witches_x_BON10            -1.6073      0.357     -4.500      0.000      -2.307      -0.907
# faction_auren_x_SCORE2             -0.4843      0.671     -0.721      0.471      -1.800       0.832
# faction_auren_x_SCORE3              0.7608      0.667      1.140      0.254      -0.547       2.069
# faction_auren_x_SCORE4              0.8395      0.687      1.222      0.222      -0.508       2.187
# faction_auren_x_SCORE5              0.4573      0.674      0.679      0.497      -0.863       1.778
# faction_auren_x_SCORE6              0.7229      0.678      1.066      0.286      -0.606       2.052
# faction_auren_x_SCORE7              1.7556      0.694      2.529      0.011       0.395       3.116
# faction_auren_x_SCORE8              1.2830      0.667      1.924      0.054      -0.024       2.590
# faction_auren_x_SCORE9             -0.5806      0.654     -0.887      0.375      -1.863       0.702
# faction_chaosmagicians_x_SCORE2    -0.6265      0.315     -1.992      0.046      -1.243      -0.010
# faction_chaosmagicians_x_SCORE3    -0.6144      0.314     -1.958      0.050      -1.229       0.001
# faction_chaosmagicians_x_SCORE4     1.0805      0.329      3.282      0.001       0.435       1.726
# faction_chaosmagicians_x_SCORE5     0.1604      0.321      0.500      0.617      -0.468       0.789
# faction_chaosmagicians_x_SCORE6    -0.6925      0.314     -2.202      0.028      -1.309      -0.076
# faction_chaosmagicians_x_SCORE7    -0.1610      0.318     -0.506      0.613      -0.784       0.462
# faction_chaosmagicians_x_SCORE8    -0.5473      0.315     -1.737      0.082      -1.165       0.070
# faction_chaosmagicians_x_SCORE9    -2.4590      0.302     -8.154      0.000      -3.050      -1.868
# faction_cultists_x_SCORE2           0.6646      0.450      1.477      0.140      -0.217       1.546
# faction_cultists_x_SCORE3          -1.6344      0.433     -3.772      0.000      -2.484      -0.785
# faction_cultists_x_SCORE4          -0.3506      0.447     -0.785      0.432      -1.226       0.525
# faction_cultists_x_SCORE5           0.1276      0.432      0.296      0.767      -0.718       0.973
# faction_cultists_x_SCORE6          -1.6914      0.434     -3.901      0.000      -2.541      -0.842
# faction_cultists_x_SCORE7          -0.4406      0.437     -1.009      0.313      -1.296       0.415
# faction_cultists_x_SCORE8           0.4453      0.433      1.028      0.304      -0.404       1.295
# faction_cultists_x_SCORE9           0.2743      0.417      0.658      0.511      -0.543       1.092
# faction_darklings_x_SCORE2         -2.0738      0.268     -7.736      0.000      -2.599      -1.548
# faction_darklings_x_SCORE3         -0.6472      0.269     -2.410      0.016      -1.173      -0.121
# faction_darklings_x_SCORE4         -1.8658      0.266     -7.005      0.000      -2.388      -1.344
# faction_darklings_x_SCORE5         -1.8933      0.267     -7.096      0.000      -2.416      -1.370
# faction_darklings_x_SCORE6         -1.9230      0.268     -7.186      0.000      -2.448      -1.398
# faction_darklings_x_SCORE7         -1.6494      0.267     -6.188      0.000      -2.172      -1.127
# faction_darklings_x_SCORE8         -2.4051      0.266     -9.048      0.000      -2.926      -1.884
# faction_darklings_x_SCORE9         -1.5563      0.254     -6.123      0.000      -2.054      -1.058
# faction_dwarves_x_SCORE2           -1.2193      0.620     -1.967      0.049      -2.434      -0.005
# faction_dwarves_x_SCORE3           -2.5147      0.587     -4.282      0.000      -3.666      -1.364
# faction_dwarves_x_SCORE4           -3.1411      0.577     -5.443      0.000      -4.272      -2.010
# faction_dwarves_x_SCORE5           -2.7764      0.582     -4.774      0.000      -3.916      -1.636
# faction_dwarves_x_SCORE6           -3.2090      0.574     -5.593      0.000      -4.334      -2.084
# faction_dwarves_x_SCORE7           -4.3053      0.574     -7.498      0.000      -5.431      -3.180
# faction_dwarves_x_SCORE8           -3.0849      0.573     -5.387      0.000      -4.207      -1.963
# faction_dwarves_x_SCORE9           -3.1704      0.571     -5.557      0.000      -4.289      -2.052
# faction_engineers_x_SCORE2         -0.4877      0.346     -1.410      0.159      -1.166       0.190
# faction_engineers_x_SCORE3         -1.2681      0.354     -3.586      0.000      -1.961      -0.575
# faction_engineers_x_SCORE4         -2.1537      0.353     -6.096      0.000      -2.846      -1.461
# faction_engineers_x_SCORE5         -1.4234      0.353     -4.036      0.000      -2.115      -0.732
# faction_engineers_x_SCORE6          0.6104      0.363      1.683      0.092      -0.100       1.321
# faction_engineers_x_SCORE7         -2.3874      0.351     -6.794      0.000      -3.076      -1.699
# faction_engineers_x_SCORE8         -0.7157      0.356     -2.008      0.045      -1.414      -0.017
# faction_engineers_x_SCORE9          0.9423      0.340      2.771      0.006       0.276       1.609
# faction_fakirs_x_SCORE2             1.7777      0.915      1.943      0.052      -0.016       3.571
# faction_fakirs_x_SCORE3             4.4917      0.970      4.630      0.000       2.590       6.393
# faction_fakirs_x_SCORE4             3.5073      0.958      3.660      0.000       1.629       5.386
# faction_fakirs_x_SCORE5             4.5524      0.979      4.651      0.000       2.634       6.471
# faction_fakirs_x_SCORE6             3.0197      0.942      3.205      0.001       1.173       4.866
# faction_fakirs_x_SCORE7             5.3036      0.967      5.487      0.000       3.409       7.198
# faction_fakirs_x_SCORE8             6.0280      0.953      6.324      0.000       4.160       7.896
# faction_fakirs_x_SCORE9             3.1182      0.917      3.401      0.001       1.321       4.915
# faction_giants_x_SCORE2            -1.1599      0.631     -1.838      0.066      -2.397       0.077
# faction_giants_x_SCORE3            -1.4783      0.626     -2.362      0.018      -2.705      -0.252
# faction_giants_x_SCORE4            -0.8629      0.628     -1.374      0.169      -2.094       0.368
# faction_giants_x_SCORE5            -0.9405      0.628     -1.497      0.134      -2.172       0.291
# faction_giants_x_SCORE6            -1.0574      0.628     -1.684      0.092      -2.288       0.174
# faction_giants_x_SCORE7            -0.7093      0.630     -1.125      0.261      -1.945       0.526
# faction_giants_x_SCORE8            -2.3078      0.635     -3.634      0.000      -3.553      -1.063
# faction_giants_x_SCORE9            -2.8476      0.615     -4.629      0.000      -4.053      -1.642
# faction_halflings_x_SCORE2         -5.1984      0.477    -10.893      0.000      -6.134      -4.263
# faction_halflings_x_SCORE3         -5.7361      0.470    -12.215      0.000      -6.656      -4.816
# faction_halflings_x_SCORE4         -5.7371      0.465    -12.335      0.000      -6.649      -4.826
# faction_halflings_x_SCORE5         -3.9411      0.469     -8.395      0.000      -4.861      -3.021
# faction_halflings_x_SCORE6         -5.8751      0.469    -12.526      0.000      -6.794      -4.956
# faction_halflings_x_SCORE7         -4.4831      0.467     -9.597      0.000      -5.399      -3.568
# faction_halflings_x_SCORE8         -4.9359      0.469    -10.518      0.000      -5.856      -4.016
# faction_halflings_x_SCORE9         -5.7378      0.475    -12.081      0.000      -6.669      -4.807
# faction_mermaids_x_SCORE2           1.1245      0.347      3.237      0.001       0.444       1.805
# faction_mermaids_x_SCORE3           3.1752      0.368      8.635      0.000       2.455       3.896
# faction_mermaids_x_SCORE4           1.6435      0.348      4.718      0.000       0.961       2.326
# faction_mermaids_x_SCORE5           2.4231      0.353      6.867      0.000       1.732       3.115
# faction_mermaids_x_SCORE6           2.9277      0.357      8.190      0.000       2.227       3.628
# faction_mermaids_x_SCORE7           0.4957      0.347      1.429      0.153      -0.184       1.176
# faction_mermaids_x_SCORE8           1.2775      0.346      3.688      0.000       0.599       1.956
# faction_mermaids_x_SCORE9           1.0430      0.334      3.121      0.002       0.388       1.698
# faction_nomads_x_SCORE2             2.2103      0.317      6.962      0.000       1.588       2.832
# faction_nomads_x_SCORE3             1.1211      0.315      3.563      0.000       0.504       1.738
# faction_nomads_x_SCORE4             2.3578      0.320      7.363      0.000       1.730       2.985
# faction_nomads_x_SCORE5             1.2297      0.316      3.890      0.000       0.610       1.849
# faction_nomads_x_SCORE6             2.5372      0.316      8.023      0.000       1.917       3.157
# faction_nomads_x_SCORE7             1.9567      0.319      6.137      0.000       1.332       2.582
# faction_nomads_x_SCORE8             2.1302      0.313      6.801      0.000       1.516       2.744
# faction_nomads_x_SCORE9             0.9342      0.299      3.121      0.002       0.348       1.521
# faction_swarmlings_x_SCORE2         1.7881      0.401      4.463      0.000       1.003       2.573
# faction_swarmlings_x_SCORE3         1.2545      0.396      3.168      0.002       0.478       2.031
# faction_swarmlings_x_SCORE4         2.7069      0.406      6.665      0.000       1.911       3.503
# faction_swarmlings_x_SCORE5         1.1376      0.398      2.860      0.004       0.358       1.917
# faction_swarmlings_x_SCORE6         2.1306      0.420      5.078      0.000       1.308       2.953
# faction_swarmlings_x_SCORE7         2.6866      0.402      6.681      0.000       1.898       3.475
# faction_swarmlings_x_SCORE8         2.1496      0.418      5.148      0.000       1.331       2.968
# faction_swarmlings_x_SCORE9         0.0990      0.386      0.256      0.798      -0.658       0.856
# faction_witches_x_SCORE2            1.5111      0.356      4.245      0.000       0.813       2.209
# faction_witches_x_SCORE3            0.9616      0.350      2.746      0.006       0.275       1.648
# faction_witches_x_SCORE4            1.7804      0.353      5.046      0.000       1.089       2.472
# faction_witches_x_SCORE5            1.3987      0.353      3.957      0.000       0.706       2.091
# faction_witches_x_SCORE6            0.3952      0.343      1.154      0.249      -0.276       1.067
# faction_witches_x_SCORE7            4.2332      0.371     11.414      0.000       3.506       4.960
# faction_witches_x_SCORE8            3.1172      0.359      8.679      0.000       2.413       3.821
# faction_witches_x_SCORE9            2.0801      0.335      6.214      0.000       1.424       2.736
# ==============================================================================
# Omnibus:                     1052.135   Durbin-Watson:                   2.490
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1284.617
# Skew:                          -0.108   Prob(JB):                    1.12e-279
# Kurtosis:                       3.329   Cond. No.                         521.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Ok, well this is all pretty hard to read. It does look like at least some SCORE/BONUS tiles have an impact on the marginal scoring of factions. The way the data is presented isn't super useful, so the next step would be to turn this into a function where you could pass your score and bonus tile setup and have it return the factions ranked by their estimated marginal vp.
#
# We'll leave that for the next round. I'd like to get some feedback on if these coefficients match intution. So pick a couple factions that you know have particularly advantageous scoring or bonus tiles (or disadvantageous) and see if the coefficient reflects that.
